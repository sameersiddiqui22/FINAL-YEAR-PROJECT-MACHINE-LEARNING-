# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')

# %%
car=pd.read_csv('Book333.csv')

# %%
car.head(20)
# Out:
#                      name     company  year    Price  kms_driven fuel_type
# 0            Toyota Prado      Toyota  1997  2100000      100000    Diesel
# 1            Suzuki Bolan      Suzuki  2006   380000      100000    Petrol
# 2            Suzuki Bolan      Suzuki  1998   340000       12345       CNG
# 3             Suzuki Alto      Suzuki  2010   535000       94000    Petrol
# 4      Toyota Corolla XLI      Toyota  2013  1430000      100000    Petrol
# 5   Toyota Corrolla Altis      Toyota  2012  1620000       80000    Petrol
# 6       Suzuki Cultus VXL      Suzuki  2006   450000       65000       CNG
# 7   Toyota Corrolla Altis      Toyota  2017  2900000       10241    Petrol
# 8             Suzuki Alto      Suzuki  2009   490000       83000       CNG
# 9         Honda Civic VTi       Honda  1997   480000       50000    Petrol
# 10          Suzuki Khyber      Suzuki  1994   230000     1230000       CNG
# 11           Suzuki Liana      Suzuki  2006   535000       73000       CNG
# 12           Toyota Passo      Toyota  2006   770000       78000    Petrol
# 13  Honda Civic Prosmetic       Honda  1997   490000      100000    Petrol
# 14        Honda Civic EXi       Honda  1984   160000      170000       CNG
# 15            Suzuki Alto      Suzuki  2005   425000      200000    Petrol
# 16       Daihatsu Charade    Daihatsu  1988   180000      100000    Petrol
# 17  MitsubishiPajero Mini  Mitsubishi  1995   520000       82000    Petrol
# 18        Suzuki Margalla      Suzuki  1990   400000       10000       CNG
# 19       Honda City IVTEC       Honda  2014  1400000       69500    Petrol

# %%
car.shape
# Out:
# (2288, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2288 entries, 0 to 2287
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2288 non-null   object
#  1   company     2288 non-null   object
#  2   year        2288 non-null   int64
#  3   Price       2288 non-null   int64
#  4   kms_driven  2288 non-null   int64
#  5   fuel_type   2288 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 107.4+ KB

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2288 entries, 0 to 2287
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        2288 non-null   object
#  1   company     2288 non-null   object
#  2   year        2288 non-null   int64
#  3   Price       2288 non-null   int64
#  4   kms_driven  2288 non-null   int64
#  5   fuel_type   2288 non-null   object
# dtypes: int64(3), object(3)
# memory usage: 107.4+ KB

# %%
car.describe(include='all')
# Out:
#                name company        year         Price    kms_driven fuel_type
# count          2288    2288  2288.00000  2.288000e+03  2.288000e+03      2288
# unique          257      28         NaN           NaN           NaN         5
# top     Suzuki Alto  Suzuki         NaN           NaN           NaN    Petrol
# freq            191     914         NaN           NaN           NaN      1362
# mean            NaN     NaN  2010.00000  1.601952e+06  9.193618e+04       NaN
# std             NaN     NaN     6.82244  1.744407e+06  4.487382e+05       NaN
# min             NaN     NaN  1980.00000  5.500000e+04  0.000000e+00       NaN
# 25%             NaN     NaN  2007.00000  6.000000e+05  3.015075e+04       NaN
# 50%             NaN     NaN  2012.00000  1.125000e+06  4.600000e+04       NaN
# 75%             NaN     NaN  2015.00000  1.975000e+06  7.500000e+04       NaN
# max             NaN     NaN  2019.00000  1.550000e+07  1.000000e+07       NaN

# %%
car=car[car['Price']<60000000]

# %%
car['company'].unique()
# Out:
# array(['Toyota', 'Suzuki', 'Honda', 'Daihatsu', 'Mitsubishi', 'KIA',
#        'Nissan', 'Chevrolet', 'Daewoo', 'Hyundai', 'FAW', 'Ford', 'Skoda',
#        'Audi', 'Renault', 'Datsun', 'Suzukii', 'Volkswagen', 'Mini',
#        'BMW', "Suzuki'", 'Fiat', 'Force', 'Mercedes', 'Land', 'Jaguar',
#        'Jeep', 'Volvo'], dtype=object)

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\dell\Desktop\fyp\main\model2.ipynb Cell 11 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/fyp/main/model2.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> plt.subplots(figsize=(15,7))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/fyp/main/model2.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> ax=sns.boxplot(x='company',y='Price',data=car)
#       <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/fyp/main/model2.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
#       <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/fyp/main/model2.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> plt.show()
#
# NameError: name 'sns' is not defined

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='year',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 54.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 41.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 55.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 44.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 26.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 58.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 70.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 69.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 61.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 65.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 68.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 59.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 66.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 65.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 43.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 41.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\users\malik\appdata\local\programs\python\python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.relplot(x='kms_driven',y='Price',data=car,height=7,aspect=1.5)

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel_type',y='Price',data=car)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='Price'>

# %%
ax=sns.relplot(x='company',y='Price',data=car,hue='fuel_type',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %%
X=car[['name','company','year','kms_driven','fuel_type']]
y=car['Price']

# %%
X
# Out:
#                     name company  year  kms_driven fuel_type
# 0           Toyota Prado  Toyota  1997      100000    Diesel
# 1           Suzuki Bolan  Suzuki  2006      100000    Petrol
# 2           Suzuki Bolan  Suzuki  1998       12345       CNG
# 3            Suzuki Alto  Suzuki  2010       94000    Petrol
# 4     Toyota Corolla XLI  Toyota  2013      100000    Petrol
# ...                  ...     ...   ...         ...       ...
# 2283   Honda City Aspire   Honda  2006      131389    Petrol
# 2284  Toyota Corolla XLI  Toyota  1980       12345    Petrol
# 2285    Suzuki Mehran VX  Suzuki  2006      345888    Hybrid
# 2286         Suzuki Alto  Suzuki  2006      116500    Petrol
# 2287         Suzuki Alto  Suzuki  2011       34000       CNG
#
# [2288 rows x 5 columns]

# %%
y.shape
# Out:
# (2288,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array([' Suzuki Swift', 'Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0',
#        'Audi A6 2.0', 'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7',
#        'BMW 3 Series', 'BMW 5 Series', 'BMW 7 Series', 'BMW X1',
#        'BMW X1 sDrive20d', 'BMW X1 xDrive20d', 'Chevrolet Beat',...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Daewoo', 'Daihatsu', 'Datsun', 'FAW',
#        'Fiat', 'Force', 'Ford', 'Honda', 'Hyundai', 'Jaguar', 'Jeep',
#        'KIA', 'Land', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Suzuki', "Suzuki'", 'Suzukii', 'Toyota',
#        'Volkswagen', 'Volvo'], dtype=object),
#                                                                             array(['CNG', 'Diesel', 'Hybrid', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.15476975799953097

# %%
scores=[]
for i in range(3000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 2004

# %%
scores[np.argmax(scores)]
# Out:
# 0.24449885071590682

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Hyundai Santro Xing','Hyundai',2007,45000,'Petrol']).reshape(1,5)))
# Out:
# array([1288615.36721027])

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\dell\Desktop\fyp\main\model2.ipynb Cell 32 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/fyp/main/model2.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=np.argmax(scores))
#       <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/fyp/main/model2.ipynb#X43sZmlsZQ%3D%3D?line=1'>2</a> lr=LinearRegression()
#       <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/fyp/main/model2.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> pipe=make_pipeline(column_trans,lr)
#
# NameError: name 'train_test_split' is not defined

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel321.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['Hyundai Santro Xing','Hyundai',2007,45000,'Petrol']).reshape(1,5)))
# Out:
# array([1298324.99381527])

# %%
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array([' Suzuki Swift', 'Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0',
#        'Audi A6 2.0', 'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7',
#        'BMW 3 Series', 'BMW 5 Series', 'BMW 7 Series', 'BMW X1',
#        'BMW X1 sDrive20d', 'BMW X1 xDrive20d', 'Chevrolet Beat',
#        'Chevrolet Beat Diesel', 'Chevrolet Beat LS', 'Chevrolet Beat LT',
#        'Chevrolet Beat PS', 'Chevrolet Cruze LTZ', 'Chevrolet Enjoy',
#        'Chevrolet Enjoy 1.4', 'Chevrolet Joy', 'Chevrolet Sail 1.2',
#        'Chevrolet Sail UVA', 'Chevrolet Spark', 'Chevrolet Spark 1.0',
#        'Chevrolet Spark LS', 'Chevrolet Spark LT', 'Chevrolet Tavera LS',
#        'Chevrolet Tavera Neo', 'Daewoo Racer', 'Daihatsu Charade',
#        'Daihatsu Cuore', 'Daihatsu Hijet', 'Daihatsu Mira',
#        'Daihatsu Terios Kid', 'Datsun GO T', 'Datsun Go Plus',
#        'Datsun Redi GO', 'FAW V2', 'Fiat Linea Emotion', 'Fiat Petra ELX',
#        'Fiat Punto Emotion', 'Force Motors Force', 'Force Motors One',
#        'Ford EcoSport', 'Ford EcoSport Ambiente',
#        'Ford EcoSport Titanium', 'Ford EcoSport Trend',
#        'Ford Endeavor 4x4', 'Ford Fiesta', 'Ford Fiesta SXi', 'Ford Figo',
#        'Ford Figo Diesel', 'Ford Figo Duratorq', 'Ford Figo Petrol',
#        'Ford Fusion 1.4', 'Ford Ikon 1.3', 'Ford Ikon 1.6',
#        'Honda Accord', 'Honda Amaze', 'Honda Amaze 1.2',
#        'Honda Amaze 1.5', 'Honda BR-V', 'Honda Brio', 'Honda Brio V',
#        'Honda Brio VX', 'Honda City', 'Honda City 1.5',
#        'Honda City Aspire', 'Honda City IDSI', 'Honda City IVTEC',
#        'Honda City SV', 'Honda City VX', 'Honda City ZX',
#        'Honda Civic EXi', 'Honda Civic Prosmetic', 'Honda Civic VTi',
#        'Honda Civic VTi Oriel', 'Honda Civic VTi Oriel Prosmatec',
#        'Honda Fit', 'Honda Jazz S', 'Honda Jazz VX', 'Honda Mobilio',
#        'Honda Mobilio S', 'Honda Vamos', 'Honda WR V', 'Honda Zest',
#        'Hyundai Accent', 'Hyundai Accent Executive', 'Hyundai Accent GLE',
#        'Hyundai Accent GLX', 'Hyundai Creta', 'Hyundai Creta 1.6',
#        'Hyundai Elantra 1.8', 'Hyundai Elantra SX', 'Hyundai Elite i20',
#        'Hyundai Eon', 'Hyundai Eon D', 'Hyundai Eon Era',
#        'Hyundai Eon Magna', 'Hyundai Eon Sportz', 'Hyundai Fluidic Verna',
#        'Hyundai Getz', 'Hyundai Getz GLE', 'Hyundai Getz Prime',
#        'Hyundai Grand i10', 'Hyundai Santro', 'Hyundai Santro AE',
#        'Hyundai Santro Xing', 'Hyundai Sonata Transform', 'Hyundai Verna',
#        'Hyundai Verna 1.4', 'Hyundai Verna 1.6', 'Hyundai Verna Fluidic',
#        'Hyundai Verna Transform', 'Hyundai Verna VGT',
#        'Hyundai Xcent Base', 'Hyundai Xcent SX', 'Hyundai i10',
#        'Hyundai i10 Era', 'Hyundai i10 Magna', 'Hyundai i10 Sportz',
#        'Hyundai i20', 'Hyundai i20 Active', 'Hyundai i20 Asta',
#        'Hyundai i20 Magna', 'Hyundai i20 Select', 'Hyundai i20 Sportz',
#        'Jaguar XE XE', 'Jaguar XF 2.2', 'Jeep Wrangler Unlimited',
#        'KIA Classic', 'KIA Pride', 'KIA Sportage',
#        'Land Rover Freelander', 'Mercedes Benz A', 'Mercedes Benz B',
#        'Mercedes Benz C', 'Mercedes Benz GLA', 'Mini Cooper S',
#        'Mitsubishi Lancer', 'Mitsubishi Lancer 1.8',
#        'Mitsubishi Pajero Sport', 'MitsubishiPajero Mini',
#        'Nissan AD Van', 'Nissan Dayz', 'Nissan Dayz Highway ',
#        'Nissan Dayz Highway Star', 'Nissan March', 'Nissan Micra XL',
#        'Nissan Micra XV', 'Nissan Sunny', 'Nissan Sunny XL',
#        'Nissan Terrano XL', 'Nissan X Trail', 'Renault Duster',
#        'Renault Duster 110', 'Renault Duster 110PS', 'Renault Duster 85',
#        'Renault Duster 85PS', 'Renault Duster RxL', 'Renault Kwid',
#        'Renault Kwid 1.0', 'Renault Kwid RXT', 'Renault Lodgy 85',
#        'Renault Scala RxL', 'Skoda Fabia', 'Skoda Fabia 1.2L',
#        'Skoda Fabia Classic', 'Skoda Laura', 'Skoda Octavia Classic',
#        'Skoda Rapid Elegance', 'Skoda Superb 1.8', 'Skoda Yeti Ambition',
#        'Suzuki 800', 'Suzuki A', 'Suzuki APV', 'Suzuki Alto',
#        'Suzuki Baleno', 'Suzuki Bolan', 'Suzuki Carry', 'Suzuki Celerio',
#        'Suzuki Ciaz', 'Suzuki Cultus VX', 'Suzuki Cultus VXL',
#        'Suzuki Cultus VXR', 'Suzuki Dzire', 'Suzuki Eeco',
#        'Suzuki Ertiga', 'Suzuki Esteem', 'Suzuki Estilo', 'Suzuki Every',
#        'Suzuki FX', 'Suzuki Kei', 'Suzuki Khyber', 'Suzuki Liana',
#        'Suzuki Margalla', 'Suzuki Maruti', 'Suzuki Mehran VX',
#        'Suzuki Mehran VXR', 'Suzuki Omni', 'Suzuki Ritz', 'Suzuki S',
#        'Suzuki SX4', 'Suzuki Stingray', 'Suzuki Swift', 'Suzuki Versa',
#        'Suzuki Vitara', 'Suzuki Wagon', 'Suzuki Zen', 'Toyota Aygo',
#        'Toyota Camry', 'Toyota Corolla', 'Toyota Corolla 2.0 D',
#        'Toyota Corolla Altis', 'Toyota Corolla GLI', 'Toyota Corolla H2',
#        'Toyota Corolla XE', 'Toyota Corolla XLI', 'Toyota Corrolla Altis',
#        'Toyota Estima', 'Toyota Etios', 'Toyota Etios G',
#        'Toyota Etios GD', 'Toyota Etios Liva', 'Toyota Fortuner',
#        'Toyota Fortuner 3.0', 'Toyota Hilux', 'Toyota Innova 2.0',
#        'Toyota Innova 2.5', 'Toyota Passo', 'Toyota Prado',
#        'Toyota Premio', 'Toyota Prius', 'Toyota Probox', 'Toyota Qualis',
#        'Toyota Rush', 'Toyota Sprinter', 'Toyota Starlet', 'Toyota Surf',
#        'Toyota Vitz', 'Toyota Yaris', 'Volkswagen Jetta Comfortline',
#        'Volkswagen Jetta Highline', 'Volkswagen Passat Diesel',
#        'Volkswagen Polo', 'Volkswagen Polo Comfortline',
#        'Volkswagen Polo Highline', 'Volkswagen Polo Highline1.2L',
#        'Volkswagen Polo Trendline', 'Volkswagen Vento Comfortline',
#        'Volkswagen Vento Highline', 'Volkswagen Vento Konekt',
#        'Volvo S80 Summum'], dtype=object)
